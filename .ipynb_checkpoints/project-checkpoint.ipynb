# %%
from jupyterthemes import jtplot

jtplot.style(theme='onedork')
jtplot.style(ticks=True, grid=False, figsize=(6, 5))

import numpy as np
import os

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=14)
mpl.rc('ytick', labelsize=14)

IMAGES_PATH = os.path.join(".", "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def saveImage(img, tight_layout=True, extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, img + "." + extension)
    # print("Saving image", img)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=extension, dpi=resolution)

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
X = mnist["data"]
y = mnist["target"]
X.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %%
digit = X[5]
digitImage = digit.reshape(28, 28)
plt.imshow(digitImage, cmap='gray')
plt.show()

# %%
y[5]
# Out:
# 2

# %%
# y = y.astype(np.uint8)
for i in range(10):
    plt.imshow(X[i].reshape(28, 28), cmap='binary')
    print(y[i])
    plt.show()
# Out:
# 5
# 0
# 4
# 1
# 9
# 2
# 1
# 3
# 1
# 4

# %%
# def plot_digits(instances, images_per_row=10, **options):
#     size = 28
#     # images_per_row = min(len(instances), images_per_row)
#     images = [instance.reshape(size,size) for instance in instances]
#     n_rows = (len(instances) - 1) // images_per_row + 1
#     row_images = []
#     n_empty = n_rows * images_per_row - len(instances)
#     images.append(np.zeros((size, size * n_empty)))
#
#     for row in range(n_rows):
#         rimages = images[row * images_per_row : (row + 1) * images_per_row]
#         row_images.append(np.concatenate(rimages, axis=1))
#
#     image = np.concatenate(row_images, axis=0)
#     plt.imshow(image, cmap = mpl.cm.binary, **options)
#     plt.axis("off")
#

# %%
# plt.figure(figsize=(20,20))
# plot_digits(X[:1000], images_per_row=25)
# save_fig("more_digits_plot")
# plt.show()

# %%
X_train = X[:60000]
X_test = X[60000:]
y_train = y[:60000]
y_test = y[60000:]

# %% [markdown]
# Multiclass Classification

# %%
from sklearn.svm import SVC
svm_clf = SVC(gamma="auto", random_state=42)
svm_clf.fit(X_train[:1000], y_train[:1000])
svm_clf.predict([digit])

# %%
some_digit_scores = svm_clf.decision_function([digit])
some_digit_scores

# %%
np.argmax(some_digit_scores)

# %%
svm_clf.classes_

# %%
from sklearn.neighbors import KNeighborsClassifier
kn_clf = KNeighborsClassifier(weights='distance', n_neighbors=4)
kn_clf.fit(X_train, y_train)
kn_clf.predict([digit])

# %%
y_knn_pred = kn_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_knn_pred)
